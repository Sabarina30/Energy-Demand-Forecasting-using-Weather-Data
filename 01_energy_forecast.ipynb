# %% [markdown]
# # **Short Term Electricity Demand Forecasting using Weather Data (Delhi, 5-minute resolution)**

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/powerdemand_5min_2021_to_2024_with weather.csv")

# %%
data.shape
# Out:
# (393440, 15)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'datetime', 'Power demand', 'temp', 'dwpt', 'rhum',
#        'wdir', 'wspd', 'pres', 'year', 'month', 'day', 'hour', 'minute',
#        'moving_avg_3'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Unnamed: 0        int64
# datetime         object
# Power demand    float64
# temp            float64
# dwpt            float64
# rhum            float64
# wdir            float64
# wspd            float64
# pres            float64
# year              int64
# month             int64
# day               int64
# hour              int64
# minute            int64
# moving_avg_3    float64
# dtype: object

# %%
data.head(5)
# Out:
#    Unnamed: 0             datetime  Power demand  temp  dwpt  rhum  wdir  \
# 0           0  2021-01-01 00:30:00       2014.00   8.0   6.9  93.0   0.0
# 1           1  2021-01-01 00:35:00       2005.63   8.0   6.9  93.0   0.0
# 2           2  2021-01-01 00:40:00       1977.60   8.0   6.9  93.0   0.0
# 3           3  2021-01-01 00:45:00       1976.44   8.0   6.9  93.0   0.0
# 4           4  2021-01-01 00:50:00       1954.37   8.0   6.9  93.0   0.0
#
#    wspd    pres  year  month  day  hour  minute  moving_avg_3
# 0   0.0  1017.0  2021      1    1     0      30           NaN
# 1   0.0  1017.0  2021      1    1     0      35           NaN
# 2   0.0  1017.0  2021      1    1     0      40   1999.076667
# 3   0.0  1017.0  2021      1    1     0      45   1986.556667
# 4   0.0  1017.0  2021      1    1     0      50   1969.470000

# %%
data.isnull().sum()
# Out:
# Unnamed: 0        0
# datetime          0
# Power demand      0
# temp              0
# dwpt              0
# rhum              0
# wdir            540
# wspd              0
# pres              0
# year              0
# month             0
# day               0
# hour              0
# minute            0
# moving_avg_3      2
# dtype: int64

# %% [markdown]
# Power demand columns is the target variable.
# temp, dwpt, rhum, wdir, wspd, pres  are the weather features.
#
# 1.temp is Air Temperature (°C)
#
# 2.dwpt is Dew Point Temperature (°C) (indirectly relates to moisture in air)
#
# 3.rhum is Relative Humidity (%)
#
# 4.wdir is Wind Direction (degrees, 0–360° i.e N, E, S, W)
#
# 5.wspd is Wind Speed (m/s or km/h, depends on source)
#
# 6.pres is Air Pressure (hPa / millibars)
#
# year, month, day, hour, minute are extracted time components.

# %% [markdown]
# We can see there are 540 null value in wdir column and that can be dropped. "unnamed" column and be dropped.

# %% [markdown]
# **DATA CLEANING**

# %%
data = data.drop(columns=["Unnamed: 0"])

# %% [markdown]
# **Handling missing values**

# %% [markdown]
# By using interpolation method the missing values are handled.There are 540 missing values in wdir and 2 in miving-avg_3 column. For wind direction column linear interpolation is used and for the moving avg column forwardfill(ffill) or backwaardfill(bfill)is used.

# %%
# Interpolate wind direction
data['wdir'] = data['wdir'].interpolate(method='linear')

# %%
data[data["moving_avg_3"].isnull()]
# Out:
#               datetime  Power demand  temp  dwpt  rhum  wdir  wspd    pres  \
# 0  2021-01-01 00:30:00       2014.00   8.0   6.9  93.0   0.0   0.0  1017.0
# 1  2021-01-01 00:35:00       2005.63   8.0   6.9  93.0   0.0   0.0  1017.0
#
#    year  month  day  hour  minute  moving_avg_3
# 0  2021      1    1     0      30           NaN
# 1  2021      1    1     0      35           NaN

# %% [markdown]
# No previous values exist at the very start.Therefore bfill is used to handle missing values in Moving_avg_3 column.

# %%
# Fill missing moving average
data["moving_avg_3"] = data["moving_avg_3"].bfill()

# %%
data.isnull().sum()
# Out:
# datetime        0
# Power demand    0
# temp            0
# dwpt            0
# rhum            0
# wdir            0
# wspd            0
# pres            0
# year            0
# month           0
# day             0
# hour            0
# minute          0
# moving_avg_3    0
# dtype: int64

# %%
data.head(5)
# Out:
#               datetime  Power demand  temp  dwpt  rhum  wdir  wspd    pres  \
# 0  2021-01-01 00:30:00       2014.00   8.0   6.9  93.0   0.0   0.0  1017.0
# 1  2021-01-01 00:35:00       2005.63   8.0   6.9  93.0   0.0   0.0  1017.0
# 2  2021-01-01 00:40:00       1977.60   8.0   6.9  93.0   0.0   0.0  1017.0
# 3  2021-01-01 00:45:00       1976.44   8.0   6.9  93.0   0.0   0.0  1017.0
# 4  2021-01-01 00:50:00       1954.37   8.0   6.9  93.0   0.0   0.0  1017.0
#
#    year  month  day  hour  minute  moving_avg_3
# 0  2021      1    1     0      30   1999.076667
# 1  2021      1    1     0      35   1999.076667
# 2  2021      1    1     0      40   1999.076667
# 3  2021      1    1     0      45   1986.556667
# 4  2021      1    1     0      50   1969.470000
